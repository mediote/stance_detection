# %% [markdown]
# gostaria que te preparasses oara esta reuniao, tentando apresentar de forma mais ordenada teu plano de trabalh: o escopo que escolheste, os problemas a serem resolvidos, o que já esta feito, o que precisa ser feito, o que já anteves como avaliacao (se algo), etc

# %% [markdown]
# # Dissertação
#
# ### - Algori
