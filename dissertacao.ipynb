# %%
import pandas as pd

ids = pd.read_csv("./data/ids.csv")
tweets = pd.read_csv("./data/trump_tweets.csv")
tweets
# Out:
#                       created_at                  id   author_id  \
# 0       2016-01-01T00:03:29.000Z  682713720368140290   724599002
# 1       2016-01-01T00:22:51.000Z  682718591821721600   395484842
# 2       2016-01-01T00:23:39.000Z  682718793785815040   113457921
# 3       2016-01-01T00:34:18.000Z  682721474566696960    51623437
# 4       2016-01-01T00:39:18.000Z  682722734124711937   269651436
# ...                          ...                 ...         ...
# 119263  2016-12-30T23:17:26.000Z  814973700923682820   237509961
# 119264  2016-12-30T23:23:38.000Z  814975259912839168   237509961
# 119265  2016-12-30T23:54:53.000Z  814983125411344384  3092209045
# 119266  2016-12-30T23:57:19.000Z  814983738518110208    16362541
# 119267  2016-12-30T23:59:57.000Z  814984401746620416   494509710
#
#         in_reply_to_user_id                                               text
# 0                       NaN                      actually the biggest loser in
# ...

# %%
tweets = tweets[tweets.id.isin(ids.id)]

# %%
tweets
# Out:
# Empty DataFrame
# Columns: [created_at, id, author_id, in_reply_to_user_id, text]
# Index: []
